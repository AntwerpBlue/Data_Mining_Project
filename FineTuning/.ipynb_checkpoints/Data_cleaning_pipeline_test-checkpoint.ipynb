# %%
import pandas as pd
import numpy as np

df = pd.read_csv("bank_marketing_test.csv")
print("df.shape = " ,df.shape)
df.head()
# Out:
# df.shape =  (8000, 24)
#    age          job  marital            education  default housing loan  \
# 0   34  blue-collar  married             basic.6y       no      no   no
# 1   29       admin.  married          high.school       no     yes   no
# 2   38    housemaid  married          high.school  unknown      no   no
# 3   31     services  married          high.school  unknown      no   no
# 4   45  blue-collar  married  professional.course       no     yes   no
#
#      contact month day_of_week  ...  emp.var.rate  cons.price.idx  \
# 0  telephone   may         mon  ...           1.1          93.994
# 1  telephone   jun         fri  ...           1.4          94.465
# 2  telephone   may         thu  ...           1.1          93.994
# 3  telephone   jun         thu  ...           1.4          94.465
# 4  telephone   may         thu  ...          -1.8          93.876
#
#    cons.conf.idx euribor3m  nr.employed  feature_1  feature_2  feature_3  \
# 0          -36.4     4.857       5191.0     4.6443    38.8889        vg3
# 1          -41.8     4.959       5228.1     3.6433    32.8889        vg7
# 2          -36.4     4.860       5191.0     4.6443    42.8889        vg4
# 3          -41.8     4.866       5228.1     2.6423    33.8889        vg3
# 4          -40.0     0.683       5008.7        NaN        NaN       vg10
#
#    feature_4  feature_5
# 0        lv1       fn38
# 1        lv1        fn4
# 2        lv1       fn30
# 3        lv1        fn6
# 4       lv10       fn48
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8000 non-null   int64
#  1   job             8000 non-null   object
#  2   marital         8000 non-null   object
#  3   education       8000 non-null   object
#  4   default         8000 non-null   object
#  5   housing         8000 non-null   object
#  6   loan            8000 non-null   object
#  7   contact         8000 non-null   object
#  8   month           8000 non-null   object
#  9   day_of_week     8000 non-null   object
#  10  campaign        7997 non-null   float64
#  11  pdays           8000 non-null   int64
#  12  previous        8000 non-null   int64
#  13  poutcome        8000 non-null   object
#  14  emp.var.rate    8000 non-null   float64
#  15  cons.price.idx  8000 non-null   float64
#  16  cons.conf.idx   8000 non-null   float64
#  17  euribor3m       8000 non-null   float64
#  18  nr.employed     8000 non-null   float64
#  19  feature_1       7997 non-null   float64
#  20  feature_2       7997 non-null   float64
#  21  feature_3       8000 non-null   object
#  22  feature_4       8000 non-null   object
#  23  feature_5       8000 non-null   object
# dtypes: float64(8), int64(3), object(13)
# memory usage: 1.5+ MB

# %%
# 避免污染原始数据，先复制一个数据
df_clean = df.copy()

# %%
df_clean.columns.tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'feature_1',
#  'feature_2',
#  'feature_3',
#  'feature_4',
#  'feature_5']

# %%
# 把999改为-1，方便后面标准化
df_clean['pdays'] = df_clean['pdays'].replace(999,-1)
df_clean['pdays'].value_counts().head()
# Out:
# pdays
# -1    7661
#  3      93
#  6      91
#  4      23
#  9      17
# Name: count, dtype: int64

# %%
# 观察类别不平衡情况
df_clean['y'].value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda3\envs\test\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 观察类别不平衡情况
# ----> 2 df_clean['y'].value_counts(normalize=True)
#
# File D:\Anaconda3\envs\test\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File D:\Anaconda3\envs\test\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'y'

# %%
unknown_counts = (df_clean == "unknown").sum()
unknown_counts[unknown_counts > 0]
# Out:
# job           224
# marital        49
# education    1154
# default      5552
# housing       650
# loan          650
# dtype: int64

# %%
# 把y变成0/1变量
df_clean['y'] = df_clean['y'].map({'yes': 1, 'no': 0})
df_clean['y'].value_counts()
# Out:
# y
# 0    23124
# 1     3122
# Name: count, dtype: int64

# %%
# 找出数值列
numeric_cols = df_clean.select_dtypes(include=['int64','float64']).columns  #include包括，exclude删除
numeric_cols
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'feature_1', 'feature_2', 'y'],
#       dtype='object')

# %%
# 查看每个数值列的大致统计特征
df_clean[numeric_cols].describe()
# Out:
#                 age     campaign         pdays      previous  emp.var.rate  \
# count  26246.000000  26246.00000  26246.000000  26246.000000  26246.000000
# mean      40.154538      2.66574     -0.725863      0.181704      0.059598
# std       10.450543      2.87869      1.538588      0.506030      1.578188
# min       17.000000      1.00000     -1.000000      0.000000     -3.400000
# 25%       32.000000      1.00000     -1.000000      0.000000     -1.800000
# 50%       38.000000      2.00000     -1.000000      0.000000      1.100000
# 75%       47.000000      3.00000     -1.000000      0.000000      1.400000
# max       98.000000     56.00000     25.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed   feature_1  \
# count    26246.000000   26246.000000  26246.000000  26246.000000  26246.0000
# mean        93.580828     -40.491404      3.597076   5165.540197         inf
# std          0.586050       4.646433      1.743984     73.224175         NaN
# min         92.201000     -50.800000      0.634000   4963.600000      1.3874
# 25%         93.075000     -42.700000      1.334000   5099.100000      1.3874
# 50%         93.876000     -41.800000      4.857000   5191.000000      2.3884
# 75%         93.994000     -36.400000      4.961000   5228.100000      3.3894
# max         94.767000     -26.900000      5.045000   5228.100000         inf
#
#           feature_2             y
# count  26246.000000  26246.000000
# mean      43.707477      0.118951
# std       10.850257      0.323738
# min       19.887200      0.000000
# 25%       34.887200      0.000000
# 50%       41.887200      0.000000
# 75%       50.887200      0.000000
# max       99.887200      1.000000

# %%
# 发现F1有异常值，处理掉
df_clean['feature_1'].replace([np.inf, -np.inf], np.nan).isna().sum()
# Out:
# np.int64(11)

# %%
df_clean['feature_1'] = df_clean['feature_1'].replace([np.inf, -np.inf], np.nan)
df_clean = df_clean.dropna(subset=['feature_1'])
df_clean['feature_1'].isna().sum()
# Out:
# np.int64(0)

# %%
# 检查是否还有异常值
np.isinf(df_clean.select_dtypes(include=['float64', 'int64'])).sum()
# Out:
# age               0
# campaign          0
# pdays             0
# previous          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# feature_1         0
# feature_2         0
# y                 0
# dtype: int64

# %%
# 检查是否还有缺失值
df_clean.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# feature_1         0
# feature_2         0
# feature_3         0
# feature_4         0
# feature_5         0
# y                 0
# dtype: int64

# %%
categorical_cols = df_clean.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'feature_3',
#  'feature_4',
#  'feature_5']

# %%
from sklearn.preprocessing import LabelEncoder
df_tree_ready = df_clean.copy()
label_encoders = {} #保存到test数据中

for col in categorical_cols:
    # 为该列创建一个 LabelEncoder 实例
    le = LabelEncoder()
    
    # fit_transform 的两步操作：
    #   fit():    学习列中有哪些类别（如 ['yes','no','unknown']）
    #   transform(): 将类别转换成整数（如 [0,1,2]）
    df_tree_ready[col] = le.fit_transform(df_tree_ready[col])
    
    # 把训练好的 encoder 存进字典，后续 test 数据要用
    label_encoders[col] = le

# 再检查一次
df_tree_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26235 entries, 0 to 26245
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             26235 non-null  int64
#  1   job             26235 non-null  int64
#  2   marital         26235 non-null  int64
#  3   education       26235 non-null  int64
#  4   default         26235 non-null  int64
#  5   housing         26235 non-null  int64
#  6   loan            26235 non-null  int64
#  7   contact         26235 non-null  int64
#  8   month           26235 non-null  int64
#  9   day_of_week     26235 non-null  int64
#  10  campaign        26235 non-null  int64
#  11  pdays           26235 non-null  int64
#  12  previous        26235 non-null  int64
#  13  poutcome        26235 non-null  int64
#  14  emp.var.rate    26235 non-null  float64
#  15  cons.price.idx  26235 non-null  float64
#  16  cons.conf.idx   26235 non-null  float64
#  17  euribor3m       26235 non-null  float64
#  18  nr.employed     26235 non-null  float64
#  19  feature_1       26235 non-null  float64
#  20  feature_2       26235 non-null  float64
#  21  feature_3       26235 non-null  int64
#  22  feature_4       26235 non-null  int64
#  23  feature_5       26235 non-null  int64
#  24  y               26235 non-null  int64
# dtypes: float64(7), int64(18)
# memory usage: 5.2 MB

# %% [markdown]
# # 标准化数据，对logistic regression等模型用

# %%
df_lrsvm_ready = df_clean.copy()
categorical_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'feature_3',
#  'feature_4',
#  'feature_5']

# %%
df_lrsvm_ready = pd.get_dummies(
    df_lrsvm_ready,
    columns=categorical_cols,
    drop_first=False
)
df_lrsvm_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26235 entries, 0 to 26245
# Columns: 276 entries, age to feature_5_fn90
# dtypes: bool(264), float64(7), int64(5)
# memory usage: 9.2 MB

# %%
# 将所有 bool 类型的列转为 float，提高模型兼容性
bool_cols = df_lrsvm_ready.select_dtypes(include=['bool']).columns
df_lrsvm_ready[bool_cols] = df_lrsvm_ready[bool_cols].astype(float)

df_lrsvm_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26235 entries, 0 to 26245
# Columns: 276 entries, age to feature_5_fn90
# dtypes: float64(271), int64(5)
# memory usage: 55.4 MB

# %%
# 1. y 是标签列
y_lrsvm = df_lrsvm_ready['y']

# 2. X 是除了 y 之外的所有特征
X_lrsvm = df_lrsvm_ready.drop(columns=['y'])

# 查看一下结果
X_lrsvm.shape, y_lrsvm.shape
# Out:
# ((26235, 275), (26235,))

# %%
from sklearn.preprocessing import StandardScaler

# 1. 创建 StandardScaler 实例
#    参数说明：
#    - with_mean=True：对每列减去均值（默认）
#    - with_std=True：除以标准差（默认）
#    这是最常用的 Z-score 标准化
scaler = StandardScaler()

# 2. 使用训练集拟合 scaler（学习每一列的 mean 和 std）
#    注意：这里不能对 test 数据 fit！否则数据泄露。
scaler.fit(X_lrsvm)

# 3. 对训练集进行标准化，把数值缩放到 N(0,1)
X_lrsvm_scaled = scaler.transform(X_lrsvm)

# 4. transform 输出是 numpy array，我们转回 DataFrame，保持列名一致
X_lrsvm_scaled = pd.DataFrame(
    X_lrsvm_scaled,
    columns=X_lrsvm.columns,
    index=X_lrsvm.index
)

# 查看形状确认
X_lrsvm_scaled.shape
# Out:
# (26235, 275)

# %%
# 保存数据
df_tree_ready.to_csv("tree_data_clean.csv", index=False)
# 保存标准化后的特征矩阵
X_lrsvm_scaled.to_csv("lrsvm_X_scaled.csv", index=False)
# 保存 y
y_lrsvm.to_csv("lrsvm_y.csv", index=False)

# %%
# 保存scaler
import joblib

# 保存 scaler
joblib.dump(scaler, "lrsvm_scaler.pkl")
# Out:
# ['lrsvm_scaler.pkl']
